# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/Python_Programming_for_Data_Science/Case Study - 4'
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Python_Programming_for_Data_Science/Case Study - 4
# 'Case Study.ipynb'   Kural_Tabanlı_Sınıflandırma.pdf   persona.csv

# %%
#############################################
# Kural Tabanlı Sınıflandırma ile Potansiyel Müşteri Getirisi Hesaplama
#############################################

#############################################
# İş Problemi
#############################################
# Bir oyun şirketi müşterilerinin bazı özelliklerini kullanarak seviye tabanlı (level based) yeni müşteri tanımları (persona)
# oluşturmak ve bu yeni müşteri tanımlarına göre segmentler oluşturup bu segmentlere göre yeni gelebilecek müşterilerin şirkete
# ortalama ne kadar kazandırabileceğini tahmin etmek istemektedir.

# Örneğin: Türkiye’den IOS kullanıcısı olan 25 yaşındaki bir erkek kullanıcının ortalama ne kadar kazandırabileceği belirlenmek isteniyor.


#############################################
# Veri Seti Hikayesi
#############################################
# Persona.csv veri seti uluslararası bir oyun şirketinin sattığı ürünlerin fiyatlarını ve bu ürünleri satın alan kullanıcıların bazı
# demografik bilgilerini barındırmaktadır. Veri seti her satış işleminde oluşan kayıtlardan meydana gelmektedir. Bunun anlamı tablo
# tekilleştirilmemiştir. Diğer bir ifade ile belirli demografik özelliklere sahip bir kullanıcı birden fazla alışveriş yapmış olabilir.

# Price: Müşterinin harcama tutarı
# Source: Müşterinin bağlandığı cihaz türü
# Sex: Müşterinin cinsiyeti
# Country: Müşterinin ülkesi
# Age: Müşterinin yaşı

################# Uygulama Öncesi #####################

#    PRICE   SOURCE   SEX COUNTRY  AGE
# 0     39  android  male     bra   17
# 1     39  android  male     bra   17
# 2     49  android  male     bra   17
# 3     29  android  male     tur   17
# 4     49  android  male     tur   17

################# Uygulama Sonrası #####################

#       customers_level_based        PRICE SEGMENT
# 0   BRA_ANDROID_FEMALE_0_18  1139.800000       A
# 1  BRA_ANDROID_FEMALE_19_23  1070.600000       A
# 2  BRA_ANDROID_FEMALE_24_30   508.142857       A
# 3  BRA_ANDROID_FEMALE_31_40   233.166667       C
# 4  BRA_ANDROID_FEMALE_41_66   236.666667       C


#############################################
# PROJE GÖREVLERİ
#############################################

#############################################
# GÖREV 1: Aşağıdaki soruları yanıtlayınız.
#############################################

# Soru 1: persona.csv dosyasını okutunuz ve veri seti ile ilgili genel bilgileri gösteriniz.
import pandas as pd
pd.set_option("display.max_rows", None)
df = pd.read_csv('persona.csv')
df.head()
df.shape
df.info()

# Soru 2: Kaç unique SOURCE vardır? Frekansları nedir?
df["SOURCE"].nunique()
df["SOURCE"].value_counts()

# Soru 3: Kaç unique PRICE vardır?
df["PRICE"].nunique()

# Soru 4: Hangi PRICE'dan kaçar tane satış gerçekleşmiş?
df["PRICE"].value_counts()

# Soru 5: Hangi ülkeden kaçar tane satış olmuş?
df["COUNTRY"].value_counts()
df.groupby("COUNTRY")["PRICE"].count()

df.pivot_table(values="PRICE",index="COUNTRY",aggfunc="count")


# Soru 6: Ülkelere göre satışlardan toplam ne kadar kazanılmış?
df.groupby("COUNTRY")["PRICE"].sum()
df.groupby("COUNTRY").agg({"PRICE": "sum"})

df.pivot_table(values="PRICE",index="COUNTRY",aggfunc="sum")

# Soru 7: SOURCE türlerine göre göre satış sayıları nedir?
df["SOURCE"].value_counts()

# Soru 8: Ülkelere göre PRICE ortalamaları nedir?
df.groupby(by=['COUNTRY']).agg({"PRICE": "mean"})

# Soru 9: SOURCE'lara göre PRICE ortalamaları nedir?
df.groupby(by=['SOURCE']).agg({"PRICE": "mean"})

# Soru 10: COUNTRY-SOURCE kırılımında PRICE ortalamaları nedir?
df.groupby(by=["COUNTRY", 'SOURCE']).agg({"PRICE": "mean"})



#############################################
# GÖREV 2: COUNTRY, SOURCE, SEX, AGE kırılımında ortalama kazançlar nedir?
#############################################
df.groupby(["COUNTRY", 'SOURCE', "SEX", "AGE"]).agg({"PRICE": "mean"}).head()


#############################################
# GÖREV 3: Çıktıyı PRICE'a göre sıralayınız.
#############################################
# Önceki sorudaki çıktıyı daha iyi görebilmek için sort_values metodunu azalan olacak şekilde PRICE'a uygulayınız.
# Çıktıyı agg_df olarak kaydediniz.
agg_df = df.groupby(by=["COUNTRY", 'SOURCE', "SEX", "AGE"]).agg({"PRICE": "mean"}).sort_values("PRICE", ascending=False)
agg_df.head()


#############################################
# GÖREV 4: Indekste yer alan isimleri değişken ismine çeviriniz.
#############################################
# Üçüncü sorunun çıktısında yer alan PRICE dışındaki tüm değişkenler index isimleridir.
# Bu isimleri değişken isimlerine çeviriniz.
# İpucu: reset_index()
# agg_df.reset_index(inplace=True)
agg_df = agg_df.reset_index()
agg_df.head()


#############################################
# GÖREV 5: AGE değişkenini kategorik değişkene çeviriniz ve agg_df'e ekleyiniz.
#############################################
# Age sayısal değişkenini kategorik değişkene çeviriniz.
# Aralıkları ikna edici olacağını düşündüğünüz şekilde oluşturunuz.
# Örneğin: '0_18', '19_23', '24_30', '31_40', '41_70'

# AGE değişkeninin nerelerden bölüneceğini belirtelim:
bins = [0, 18, 23, 30, 40, agg_df["AGE"].max()]

# Bölünen noktalara karşılık isimlendirmelerin ne olacağını ifade edelim:
mylabels = ['0_18', '19_23', '24_30', '31_40', '41_' + str(agg_df["AGE"].max())]

# age'i bölelim:
agg_df["age_cat"] = pd.cut(agg_df["AGE"], bins, labels=mylabels)
agg_df.head()


#############################################
# GÖREV 6: Yeni level based müşterileri tanımlayınız ve veri setine değişken olarak ekleyiniz.
#############################################
# customers_level_based adında bir değişken tanımlayınız ve veri setine bu değişkeni ekleyiniz.
# Dikkat!
# list comp ile customers_level_based değerleri oluşturulduktan sonra bu değerlerin tekilleştirilmesi gerekmektedir.
# Örneğin birden fazla şu ifadeden olabilir: USA_ANDROID_MALE_0_18
# Bunları groupby'a alıp price ortalamalarını almak gerekmektedir.


# YÖNTEM 2
agg_df['customers_level_based'] = agg_df[['COUNTRY', 'SOURCE', 'SEX', 'age_cat']].agg(lambda x: '_'.join(x).upper(), axis=1)


# YÖNTEM 3
agg_df["customers_level_based"] = ['_'.join(i).upper() for i in agg_df.drop(["AGE", "PRICE"], axis=1).values]


# YÖNTEM 1
# değişken isimleri:
agg_df.columns

# gözlem değerlerine nasıl erişiriz?
for row in agg_df.values:
    print(row)

# COUNTRY, SOURCE, SEX ve age_cat değişkenlerinin DEĞERLERİNİ yan yana koymak ve alt tireyle birleştirmek istiyoruz.
# Bunu list comprehension ile yapabiliriz.
# Yukarıdaki döngüdeki gözlem değerlerinin bize lazım olanlarını seçecek şekilde işlemi gerçekletirelim:
[row[0].upper() + "_" + row[1].upper() + "_" + row[2].upper() + "_" + row[5].upper() for row in agg_df.values]

# Veri setine ekleyelim:
agg_df["customers_level_based"] = [row[0].upper() + "_" + row[1].upper() + "_" + row[2].upper() + "_" + row[5].upper() for row in agg_df.values]
agg_df.head()

# Gereksiz değişkenleri çıkaralım:
agg_df = agg_df[["customers_level_based", "PRICE"]]
agg_df.head()

for i in agg_df["customers_level_based"].values:
    print(i.split("_"))


# Amacımıza bir adım daha yaklaştık.
# Burada ufak bir problem var. Birçok aynı segment olacak.
# örneğin USA_ANDROID_MALE_0_18 segmentinden birçok sayıda olabilir.
# kontrol edelim:
agg_df["customers_level_based"].value_counts()

# Bu sebeple segmentlere göre groupby yaptıktan sonra price ortalamalarını almalı ve segmentleri tekilleştirmeliyiz.
agg_df = agg_df.groupby("customers_level_based").agg({"PRICE": "mean"})

# customers_level_based index'te yer almaktadır. Bunu değişkene çevirelim.
agg_df = agg_df.reset_index()
agg_df.head()

# kontrol edelim. her bir persona'nın 1 tane olmasını bekleriz:
agg_df["customers_level_based"].value_counts()
agg_df.head()


#############################################
# GÖREV 7: Yeni müşterileri (USA_ANDROID_MALE_0_18) segmentlere ayırınız.
#############################################
# PRICE'a göre segmentlere ayırınız,
# segmentleri "SEGMENT" isimlendirmesi ile agg_df'e ekleyiniz,
# segmentleri betimleyiniz,
agg_df["SEGMENT"] = pd.qcut(agg_df["PRICE"], 4, labels=["D", "C", "B", "A"])
agg_df.head(30)
agg_df.groupby("SEGMENT").agg({"PRICE": "mean"})



#############################################
# GÖREV 8: Yeni gelen müşterileri sınıflandırınız ne kadar gelir getirebileceğini tahmin ediniz.
#############################################
# 33 yaşında ANDROID kullanan bir Türk kadını hangi segmente aittir ve ortalama ne kadar gelir kazandırması beklenir?
new_user = "TUR_ANDROID_FEMALE_31_40"
agg_df[agg_df["customers_level_based"] == new_user]

# 35 yaşında IOS kullanan bir Fransız kadını hangi segmente ve ortalama ne kadar gelir kazandırması beklenir?
new_user = "FRA_IOS_FEMALE_31_40"
agg_df[agg_df["customers_level_based"] == new_user]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PRICE    5000 non-null   int64
#  1   SOURCE   5000 non-null   object
#  2   SEX      5000 non-null   object
#  3   COUNTRY  5000 non-null   object
#  4   AGE      5000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 234.4+ KB
# ['bra' 'android' 'male' 46 59.0 '41_66'
#  'BRA_ANDROID_MALE_41_66_BRA_ANDROID_MALE_41_66']
# ['usa' 'android' 'male' 36 59.0 '31_40'
#  'USA_ANDROID_MALE_31_40_USA_ANDROID_MALE_31_40']
# ['fra' 'android' 'female' 24 59.0 '24_30'
#  'FRA_ANDROID_FEMALE_24_30_FRA_ANDROID_FEMALE_24_30']
# ['usa' 'ios' 'male' 32 54.0 '31_40'
#  'USA_IOS_MALE_31_40_USA_IOS_MALE_31_40']
# ['deu' 'android' 'female' 36 49.0 '31_40'
#  'DEU_ANDROID_FEMALE_31_40_DEU_ANDROID_FEMALE_31_40']
# ['deu' 'android' 'female' 51 49.0 '41_66'
#  'DEU_ANDROID_FEMALE_41_66_DEU_ANDROID_FEMALE_41_66']
# ['deu' 'ios' 'male' 20 49.0 '19_23'
#  'DEU_IOS_MALE_19_23_DEU_IOS_MALE_19_23']
# ['usa' 'android' 'female' 47 49.0 '41_66'
#  'USA_ANDROID_FEMALE_41_66_USA_ANDROID_FEMALE_41_66']
# ['fra' 'ios' 'male' 20 49.0 '19_23'
#  'FRA_IOS_MALE_19_23_FRA_IOS_MALE_19_23']
# ['usa' 'ios' 'male' 59 46.5 '41_66'
#  'USA_IOS_MALE_41_66_USA_IOS_MALE_41_66']
# ['deu' 'android' 'male' 15 46.5 '0_18'
#  'DEU_ANDROID_MALE_0_18_DEU_ANDROID_MALE_0_18']
# ['bra' 'android' 'female' 30 45.666666666666664 '24_30'
#  'BRA_ANDROID_FEMALE_24_30_BRA_ANDROID_FEMALE_24_30']
# ['usa' 'android' 'female' 61 45.666666666666664 '41_66'
#  'USA_ANDROID_FEMALE_41_66_USA_ANDROID_FEMALE_41_66']
# ['tur' 'ios' 'male' 24 45.0 '24_30'
#  'TUR_IOS_MALE_24_30_TUR_IOS_MALE_24_30']
# ['deu' 'android' 'male' 34 45.0 '31_40'
#  'DEU_ANDROID_MALE_31_40_DEU_ANDROID_MALE_31_40']
# ['tur' 'ios' 'female' 18 44.0 '0_18'
#  'TUR_IOS_FEMALE_0_18_TUR_IOS_FEMALE_0_18']
# ['bra' 'android' 'female' 43 44.0 '41_66'
#  'BRA_ANDROID_FEMALE_41_66_BRA_ANDROID_FEMALE_41_66']
# ['bra' 'ios' 'female' 22 44.0 '19_23'
#  'BRA_IOS_FEMALE_19_23_BRA_IOS_FEMALE_19_23']
# ['tur' 'android' 'female' 32 43.0 '31_40'
#  'TUR_ANDROID_FEMALE_31_40_TUR_ANDROID_FEMALE_31_40']
# ['bra' 'android' 'female' 39 43.0 '31_40'
#  'BRA_ANDROID_FEMALE_31_40_BRA_ANDROID_FEMALE_31_40']
# ['tur' 'ios' 'male' 37 42.333333333333336 '31_40'
#  'TUR_IOS_MALE_31_40_TUR_IOS_MALE_31_40']
# ['tur' 'android' 'male' 15 42.333333333333336 '0_18'
#  'TUR_ANDROID_MALE_0_18_TUR_ANDROID_MALE_0_18']
# ['usa' 'ios' 'male' 28 42.333333333333336 '24_30'
#  'USA_IOS_MALE_24_30_USA_IOS_MALE_24_30']
# ['bra' 'ios' 'male' 43 42.333333333333336 '41_66'
#  'BRA_IOS_MALE_41_66_BRA_IOS_MALE_41_66']
# ['deu' 'android' 'male' 20 41.72727272727273 '19_23'
#  'DEU_ANDROID_MALE_19_23_DEU_ANDROID_MALE_19_23']
# ['usa' 'ios' 'male' 30 41.72727272727273 '24_30'
#  'USA_IOS_MALE_24_30_USA_IOS_MALE_24_30']
# ['tur' 'android' 'female' 18 41.5 '0_18'
#  'TUR_ANDROID_FEMALE_0_18_TUR_ANDROID_FEMALE_0_18']
# ['usa' 'android' 'male' 47 41.5 '41_66'
#  'USA_ANDROID_MALE_41_66_USA_ANDROID_MALE_41_66']
# ['tur' 'android' 'male' 25 41.5 '24_30'
#  'TUR_ANDROID_MALE_24_30_TUR_ANDROID_MALE_24_30']
# ['usa' 'ios' 'female' 59 41.5 '41_66'
#  'USA_IOS_FEMALE_41_66_USA_IOS_FEMALE_41_66']
# ['fra' 'android' 'male' 23 41.30769230769231 '19_23'
#  'FRA_ANDROID_MALE_19_23_FRA_ANDROID_MALE_19_23']
# ['usa' 'ios' 'male' 31 41.0 '31_40'
#  'USA_IOS_MALE_31_40_USA_IOS_MALE_31_40']
# ['tur' 'android' 'female' 15 41.0 '0_18'
#  'TUR_ANDROID_FEMALE_0_18_TUR_ANDROID_FEMALE_0_18']
# ['fra' 'ios' 'male' 17 40.666666666666664 '0_18'
#  'FRA_IOS_MALE_0_18_FRA_IOS_MALE_0_18']
# ['tur' 'ios' 'female' 21 40.666666666666664 '19_23'
#  'TUR_IOS_FEMALE_19_23_TUR_IOS_FEMALE_19_23']
# ['tur' 'android' 'female' 31 40.666666666666664 '31_40'
#  'TUR_ANDROID_FEMALE_31_40_TUR_ANDROID_FEMALE_31_40']
# ['tur' 'android' 'male' 27 40.666666666666664 '24_30'
#  'TUR_ANDROID_MALE_24_30_TUR_ANDROID_MALE_24_30']
# ['fra' 'android' 'male' 19 40.53846153846154 '19_23'
#  'FRA_ANDROID_MALE_19_23_FRA_ANDROID_MALE_19_23']
# ['bra' 'android' 'male' 24 40.42857142857143 '24_30'
#  'BRA_ANDROID_MALE_24_30_BRA_ANDROID_MALE_24_30']
# ['can' 'android' 'male' 30 40.25 '24_30'
#  'CAN_ANDROID_MALE_24_30_CAN_ANDROID_MALE_24_30']
# ['can' 'android' 'male' 20 40.111111111111114 '19_23'
#  'CAN_ANDROID_MALE_19_23_CAN_ANDROID_MALE_19_23']
# ['usa' 'android' 'male' 43 39.90909090909091 '41_66'
#  'USA_ANDROID_MALE_41_66_USA_ANDROID_MALE_41_66']
# ['tur' 'android' 'male' 26 39.666666666666664 '24_30'
#  'TUR_ANDROID_MALE_24_30_TUR_ANDROID_MALE_24_30']
# ['bra' 'android' 'male' 40 39.625 '31_40'
#  'BRA_ANDROID_MALE_31_40_BRA_ANDROID_MALE_31_40']
# ['bra' 'android' 'male' 15 39.3448275862069 '0_18'
#  'BRA_ANDROID_MALE_0_18_BRA_ANDROID_MALE_0_18']
# ['usa' 'ios' 'female' 19 39.285714285714285 '19_23'
#  'USA_IOS_FEMALE_19_23_USA_IOS_FEMALE_19_23']
# ['tur' 'android' 'male' 49 39.0 '41_66'
#  'TUR_ANDROID_MALE_41_66_TUR_ANDROID_MALE_41_66']
# ['bra' 'ios' 'female' 19 39.0 '19_23'
#  'BRA_IOS_FEMALE_19_23_BRA_IOS_FEMALE_19_23']
# ['usa' 'ios' 'male' 50 39.0 '41_66'
#  'USA_IOS_MALE_41_66_USA_IOS_MALE_41_66']
# ['bra' 'ios' 'female' 25 39.0 '24_30'
#  'BRA_IOS_FEMALE_24_30_BRA_IOS_FEMALE_24_30']
# ['deu' 'android' 'female' 38 39.0 '31_40'
#  'DEU_ANDROID_FEMALE_31_40_DEU_ANDROID_FEMALE_31_40']
# ['deu' 'ios' 'male' 16 39.0 '0_18' 'DEU_IOS_MALE_0_18_DEU_IOS_MALE_0_18']
# ['fra' 'android' 'female' 21 39.0 '19_23'
#  'FRA_ANDROID_FEMALE_19_23_FRA_ANDROID_FEMALE_19_23']
# ['fra' 'android' 'male' 33 39.0 '31_40'
#  'FRA_ANDROID_MALE_31_40_FRA_ANDROID_MALE_31_40']
# ['tur' 'ios' 'female' 31 39.0 '31_40'
#  'TUR_IOS_FEMALE_31_40_TUR_IOS_FEMALE_31_40']
# ['fra' 'ios' 'male' 51 39.0 '41_66'
#  'FRA_IOS_MALE_41_66_FRA_IOS_MALE_41_66']
# ['bra' 'android' 'female' 32 39.0 '31_40'
#  'BRA_ANDROID_FEMALE_31_40_BRA_ANDROID_FEMALE_31_40']
# ['tur' 'ios' 'male' 16 39.0 '0_18' 'TUR_IOS_MALE_0_18_TUR_IOS_MALE_0_18']
# ['bra' 'ios' 'female' 42 39.0 '41_66'
#  'BRA_IOS_FEMALE_41_66_BRA_IOS_FEMALE_41_66']
# ['tur' 'android' 'male' 17 39.0 '0_18'
#  'TUR_ANDROID_MALE_0_18_TUR_ANDROID_MALE_0_18']
# ['tur' 'android' 'female' 49 39.0 '41_66'
#  'TUR_ANDROID_FEMALE_41_66_TUR_ANDROID_FEMALE_41_66']
# ['bra' 'android' 'female' 15 38.714285714285715 '0_18'
#  'BRA_ANDROID_FEMALE_0_18_BRA_ANDROID_FEMALE_0_18']
# ['usa' 'ios' 'male' 21 38.53488372093023 '19_23'
#  'USA_IOS_MALE_19_23_USA_IOS_MALE_19_23']
# ['usa' 'ios' 'female' 17 38.45945945945946 '0_18'
#  'USA_IOS_FEMALE_0_18_USA_IOS_FEMALE_0_18']
# ['fra' 'ios' 'male' 31 38.375 '31_40'
#  'FRA_IOS_MALE_31_40_FRA_IOS_MALE_31_40']
# ['tur' 'android' 'male' 16 38.285714285714285 '0_18'
#  'TUR_ANDROID_MALE_0_18_TUR_ANDROID_MALE_0_18']
# ['deu' 'android' 'male' 37 38.166666666666664 '31_40'
#  'DEU_ANDROID_MALE_31_40_DEU_ANDROID_MALE_31_40']
# ['usa' 'ios' 'female' 25 38.0 '24_30'
#  'USA_IOS_FEMALE_24_30_USA_IOS_FEMALE_24_30']
# ['deu' 'ios' 'female' 17 37.8235294117647 '0_18'
#  'DEU_IOS_FEMALE_0_18_DEU_IOS_FEMALE_0_18']
# ['can' 'ios' 'male' 17 37.666666666666664 '0_18'
#  'CAN_IOS_MALE_0_18_CAN_IOS_MALE_0_18']
# ['can' 'android' 'male' 49 37.57142857142857 '41_66'
#  'CAN_ANDROID_MALE_41_66_CAN_ANDROID_MALE_41_66']
# ['bra' 'android' 'female' 29 37.57142857142857 '24_30'
#  'BRA_ANDROID_FEMALE_24_30_BRA_ANDROID_FEMALE_24_30']
# ['tur' 'android' 'female' 26 37.57142857142857 '24_30'
#  'TUR_ANDROID_FEMALE_24_30_TUR_ANDROID_FEMALE_24_30']
# ['can' 'ios' 'male' 15 37.57142857142857 '0_18'
#  'CAN_IOS_MALE_0_18_CAN_IOS_MALE_0_18']
# ['bra' 'ios' 'male' 33 37.57142857142857 '31_40'
#  'BRA_IOS_MALE_31_40_BRA_IOS_MALE_31_40']
# ['fra' 'android' 'female' 15 37.57142857142857 '0_18'
#  'FRA_ANDROID_FEMALE_0_18_FRA_ANDROID_FEMALE_0_18']
# ['deu' 'ios' 'female' 18 37.333333333333336 '0_18'
#  'DEU_IOS_FEMALE_0_18_DEU_IOS_FEMALE_0_18']
# ['can' 'android' 'female' 18 37.333333333333336 '0_18'
#  'CAN_ANDROID_FEMALE_0_18_CAN_ANDROID_FEMALE_0_18']
# ['tur' 'ios' 'female' 20 37.333333333333336 '19_23'
#  'TUR_IOS_FEMALE_19_23_TUR_IOS_FEMALE_19_23']
# ['deu' 'android' 'male' 23 37.333333333333336 '19_23'
#  'DEU_ANDROID_MALE_19_23_DEU_ANDROID_MALE_19_23']
# ['bra' 'android' 'female' 21 37.292682926829265 '19_23'
#  'BRA_ANDROID_FEMALE_19_23_BRA_ANDROID_FEMALE_19_23']
# ['usa' 'android' 'female' 33 37.18181818181818 '31_40'
#  'USA_ANDROID_FEMALE_31_40_USA_ANDROID_FEMALE_31_40']
# ['bra' 'ios' 'male' 22 37.18181818181818 '19_23'
#  'BRA_IOS_MALE_19_23_BRA_IOS_MALE_19_23']
# ['bra' 'android' 'male' 17 37.1578947368421 '0_18'
#  'BRA_ANDROID_MALE_0_18_BRA_ANDROID_MALE_0_18']
# ['bra' 'android' 'male' 26 37.095238095238095 '24_30'
#  'BRA_ANDROID_MALE_24_30_BRA_ANDROID_MALE_24_30']
# ['usa' 'android' 'male' 26 37.0 '24_30'
#  'USA_ANDROID_MALE_24_30_USA_ANDROID_MALE_24_30']
# ['tur' 'android' 'female' 21 37.0 '19_23'
#  'TUR_ANDROID_FEMALE_19_23_TUR_ANDROID_FEMALE_19_23']
# ['deu' 'ios' 'male' 42 37.0 '41_66'
#  'DEU_IOS_MALE_41_66_DEU_IOS_MALE_41_66']
# ['bra' 'android' 'female' 56 37.0 '41_66'
#  'BRA_ANDROID_FEMALE_41_66_BRA_ANDROID_FEMALE_41_66']
# ['bra' 'ios' 'male' 15 36.878787878787875 '0_18'
#  'BRA_IOS_MALE_0_18_BRA_IOS_MALE_0_18']
# ['usa' 'ios' 'female' 26 36.857142857142854 '24_30'
#  'USA_IOS_FEMALE_24_30_USA_IOS_FEMALE_24_30']
# ['bra' 'ios' 'female' 15 36.77777777777778 '0_18'
#  'BRA_IOS_FEMALE_0_18_BRA_IOS_FEMALE_0_18']
# ['bra' 'ios' 'male' 35 36.77777777777778 '31_40'
#  'BRA_IOS_MALE_31_40_BRA_IOS_MALE_31_40']
# ['fra' 'android' 'female' 16 36.72727272727273 '0_18'
#  'FRA_ANDROID_FEMALE_0_18_FRA_ANDROID_FEMALE_0_18']
# ['usa' 'android' 'male' 20 36.64705882352941 '19_23'
#  'USA_ANDROID_MALE_19_23_USA_ANDROID_MALE_19_23']
# ['bra' 'ios' 'female' 18 36.5 '0_18'
#  'BRA_IOS_FEMALE_0_18_BRA_IOS_FEMALE_0_18']
# ['bra' 'android' 'male' 44 36.5 '41_66'
#  'BRA_ANDROID_MALE_41_66_BRA_ANDROID_MALE_41_66']
# ['bra' 'android' 'female' 24 36.5 '24_30'
#  'BRA_ANDROID_FEMALE_24_30_BRA_ANDROID_FEMALE_24_30']
# ['usa' 'android' 'male' 30 36.142857142857146 '24_30'
#  'USA_ANDROID_MALE_24_30_USA_ANDROID_MALE_24_30']
# ['tur' 'android' 'female' 52 36.142857142857146 '41_66'
#  'TUR_ANDROID_FEMALE_41_66_TUR_ANDROID_FEMALE_41_66']
# ['usa' 'ios' 'female' 28 36.142857142857146 '24_30'
#  'USA_IOS_FEMALE_24_30_USA_IOS_FEMALE_24_30']
# ['deu' 'ios' 'female' 26 36.0 '24_30'
#  'DEU_IOS_FEMALE_24_30_DEU_IOS_FEMALE_24_30']
# ['can' 'android' 'male' 15 36.0 '0_18'
#  'CAN_ANDROID_MALE_0_18_CAN_ANDROID_MALE_0_18']
# ['bra' 'android' 'female' 16 35.94444444444444 '0_18'
#  'BRA_ANDROID_FEMALE_0_18_BRA_ANDROID_FEMALE_0_18']
# ['tur' 'android' 'male' 24 35.92307692307692 '24_30'
#  'TUR_ANDROID_MALE_24_30_TUR_ANDROID_MALE_24_30']
# ['usa' 'android' 'male' 51 35.875 '41_66'
#  'USA_ANDROID_MALE_41_66_USA_ANDROID_MALE_41_66']
# ['usa' 'ios' 'female' 21 35.8 '19_23'
#  'USA_IOS_FEMALE_19_23_USA_IOS_FEMALE_19_23']
# ['usa' 'android' 'female' 19 35.76470588235294 '19_23'
#  'USA_ANDROID_FEMALE_19_23_USA_ANDROID_FEMALE_19_23']
# ['fra' 'ios' 'male' 19 35.666666666666664 '19_23'
#  'FRA_IOS_MALE_19_23_FRA_IOS_MALE_19_23']
# ['fra' 'android' 'male' 55 35.666666666666664 '41_66'
#  'FRA_ANDROID_MALE_41_66_FRA_ANDROID_MALE_41_66']
# ['bra' 'android' 'male' 41 35.666666666666664 '41_66'
#  'BRA_ANDROID_MALE_41_66_BRA_ANDROID_MALE_41_66']
# ['tur' 'android' 'male' 22 35.666666666666664 '19_23'
#  'TUR_ANDROID_MALE_19_23_TUR_ANDROID_MALE_19_23']
# ['bra' 'android' 'female' 25 35.666666666666664 '24_30'
#  'BRA_ANDROID_FEMALE_24_30_BRA_ANDROID_FEMALE_24_30']
# ['usa' 'android' 'female' 35 35.666666666666664 '31_40'
#  'USA_ANDROID_FEMALE_31_40_USA_ANDROID_FEMALE_31_40']
# ['usa' 'ios' 'female' 29 35.666666666666664 '24_30'
#  'USA_IOS_FEMALE_24_30_USA_IOS_FEMALE_24_30']
# ['bra' 'android' 'female' 17 35.666666666666664 '0_18'
#  'BRA_ANDROID_FEMALE_0_18_BRA_ANDROID_FEMALE_0_18']
# ['tur' 'ios' 'female' 19 35.666666666666664 '19_23'
#  'TUR_IOS_FEMALE_19_23_TUR_IOS_FEMALE_19_23']
# ['deu' 'ios' 'female' 16 35.557377049180324 '0_18'
#  'DEU_IOS_FEMALE_0_18_DEU_IOS_FEMALE_0_18']
# ['usa' 'android' 'male' 41 35.42857142857143 '41_66'
#  'USA_ANDROID_MALE_41_66_USA_ANDROID_MALE_41_66']
# ['bra' 'android' 'male' 20 35.4 '19_23'
#  'BRA_ANDROID_MALE_19_23_BRA_ANDROID_MALE_19_23']
# ['deu' 'android' 'male' 33 35.36363636363637 '31_40'
#  'DEU_ANDROID_MALE_31_40_DEU_ANDROID_MALE_31_40']
# ['bra' 'ios' 'female' 33 35.36363636363637 '31_40'
#  'BRA_IOS_FEMALE_31_40_BRA_IOS_FEMALE_31_40']
# ['bra' 'ios' 'female' 45 35.36363636363637 '41_66'
#  'BRA_IOS_FEMALE_41_66_BRA_IOS_FEMALE_41_66']
# ['bra' 'android' 'male' 30 35.36363636363637 '24_30'
#  'BRA_ANDROID_MALE_24_30_BRA_ANDROID_MALE_24_30']
# ['deu' 'android' 'female' 24 35.36363636363637 '24_30'
#  'DEU_ANDROID_FEMALE_24_30_DEU_ANDROID_FEMALE_24_30']
# ['bra' 'ios' 'male' 17 35.333333333333336 '0_18'
#  'BRA_IOS_MALE_0_18_BRA_IOS_MALE_0_18']
# ['bra' 'android' 'male' 21 35.25 '19_23'
#  'BRA_ANDROID_MALE_19_23_BRA_ANDROID_MALE_19_23']
# ['usa' 'android' 'female' 49 35.25 '41_66'
#  'USA_ANDROID_FEMALE_41_66_USA_ANDROID_FEMALE_41_66']
# ['bra' 'android' 'male' 19 35.21621621621622 '19_23'
#  'BRA_ANDROID_MALE_19_23_BRA_ANDROID_MALE_19_23']
# ['bra' 'android' 'female' 19 35.206896551724135 '19_23'
#  'BRA_ANDROID_FEMALE_19_23_BRA_ANDROID_FEMALE_19_23']
# ['usa' 'android' 'male' 18 35.19047619047619 '0_18'
#  'USA_ANDROID_MALE_0_18_USA_ANDROID_MALE_0_18']
# ['bra' 'ios' 'female' 37 35.111111111111114 '31_40'
#  'BRA_IOS_FEMALE_31_40_BRA_IOS_FEMALE_31_40']
# ['usa' 'ios' 'male' 27 35.111111111111114 '24_30'
#  'USA_IOS_MALE_24_30_USA_IOS_MALE_24_30']
# ['bra' 'android' 'female' 31 35.09756097560975 '31_40'
#  'BRA_ANDROID_FEMALE_31_40_BRA_ANDROID_FEMALE_31_40']
# ['usa' 'ios' 'female' 20 35.0 '19_23'
#  'USA_IOS_FEMALE_19_23_USA_IOS_FEMALE_19_23']
# ['usa' 'android' 'female' 31 35.0 '31_40'
#  'USA_ANDROID_FEMALE_31_40_USA_ANDROID_FEMALE_31_40']
# ['fra' 'ios' 'male' 22 35.0 '19_23'
#  'FRA_IOS_MALE_19_23_FRA_IOS_MALE_19_23']
# ['deu' 'android' 'female' 22 35.0 '19_23'
#  'DEU_ANDROID_FEMALE_19_23_DEU_ANDROID_FEMALE_19_23']
# ['can' 'ios' 'male' 16 35.0 '0_18' 'CAN_IOS_MALE_0_18_CAN_IOS_MALE_0_18']
# ['deu' 'ios' 'male' 17 35.0 '0_18' 'DEU_IOS_MALE_0_18_DEU_IOS_MALE_0_18']
# ['usa' 'ios' 'female' 65 35.0 '41_66'
#  'USA_IOS_FEMALE_41_66_USA_IOS_FEMALE_41_66']
# ['deu' 'ios' 'male' 25 35.0 '24_30'
#  'DEU_IOS_MALE_24_30_DEU_IOS_MALE_24_30']
# ['bra' 'android' 'female' 22 34.945945945945944 '19_23'
#  'BRA_ANDROID_FEMALE_19_23_BRA_ANDROID_FEMALE_19_23']
# ['usa' 'android' 'female' 16 34.90163934426229 '0_18'
#  'USA_ANDROID_FEMALE_0_18_USA_ANDROID_FEMALE_0_18']
# ['bra' 'ios' 'male' 23 34.88235294117647 '19_23'
#  'BRA_IOS_MALE_19_23_BRA_IOS_MALE_19_23']
# ['usa' 'android' 'male' 23 34.84905660377358 '19_23'
#  'USA_ANDROID_MALE_19_23_USA_ANDROID_MALE_19_23']
# ['tur' 'ios' 'male' 17 34.806451612903224 '0_18'
#  'TUR_IOS_MALE_0_18_TUR_IOS_MALE_0_18']
# ['usa' 'android' 'female' 28 34.78947368421053 '24_30'
#  'USA_ANDROID_FEMALE_24_30_USA_ANDROID_FEMALE_24_30']
# ['usa' 'ios' 'male' 16 34.714285714285715 '0_18'
#  'USA_IOS_MALE_0_18_USA_IOS_MALE_0_18']
# ['bra' 'ios' 'male' 34 34.714285714285715 '31_40'
#  'BRA_IOS_MALE_31_40_BRA_IOS_MALE_31_40']
# ['usa' 'android' 'male' 22 34.714285714285715 '19_23'
#  'USA_ANDROID_MALE_19_23_USA_ANDROID_MALE_19_23']
# ['usa' 'android' 'male' 35 34.714285714285715 '31_40'
#  'USA_ANDROID_MALE_31_40_USA_ANDROID_MALE_31_40']
# ['usa' 'android' 'male' 31 34.714285714285715 '31_40'
#  'USA_ANDROID_MALE_31_40_USA_ANDROID_MALE_31_40']
# ['usa' 'ios' 'female' 47 34.714285714285715 '41_66'
#  'USA_IOS_FEMALE_41_66_USA_IOS_FEMALE_41_66']
# ['usa' 'android' 'male' 15 34.663716814159294 '0_18'
#  'USA_ANDROID_MALE_0_18_USA_ANDROID_MALE_0_18']
# ['fra' 'android' 'female' 17 34.65217391304348 '0_18'
#  'FRA_ANDROID_FEMALE_0_18_FRA_ANDROID_FEMALE_0_18']
# ['usa' 'android' 'female' 17 34.625 '0_18'
#  'USA_ANDROID_FEMALE_0_18_USA_ANDROID_FEMALE_0_18']
# ['usa' 'ios' 'male' 18 34.57692307692308 '0_18'
#  'USA_IOS_MALE_0_18_USA_IOS_MALE_0_18']
# ['bra' 'android' 'female' 38 34.55555555555556 '31_40'
#  'BRA_ANDROID_FEMALE_31_40_BRA_ANDROID_FEMALE_31_40']
# ['usa' 'ios' 'female' 33 34.55555555555556 '31_40'
#  'USA_IOS_FEMALE_31_40_USA_IOS_FEMALE_31_40']
# ['tur' 'android' 'female' 16 34.55555555555556 '0_18'
#  'TUR_ANDROID_FEMALE_0_18_TUR_ANDROID_FEMALE_0_18']
# ['deu' 'android' 'female' 25 34.45454545454545 '24_30'
#  'DEU_ANDROID_FEMALE_24_30_DEU_ANDROID_FEMALE_24_30']
# ['usa' 'android' 'male' 17 34.45454545454545 '0_18'
#  'USA_ANDROID_MALE_0_18_USA_ANDROID_MALE_0_18']
# ['usa' 'android' 'male' 28 34.38461538461539 '24_30'
#  'USA_ANDROID_MALE_24_30_USA_ANDROID_MALE_24_30']
# ['bra' 'ios' 'female' 26 34.333333333333336 '24_30'
#  'BRA_IOS_FEMALE_24_30_BRA_IOS_FEMALE_24_30']
# ['usa' 'android' 'female' 21 34.18518518518518 '19_23'
#  'USA_ANDROID_FEMALE_19_23_USA_ANDROID_FEMALE_19_23']
# ['bra' 'ios' 'female' 54 34.0 '41_66'
#  'BRA_IOS_FEMALE_41_66_BRA_IOS_FEMALE_41_66']
# ['deu' 'android' 'female' 23 34.0 '19_23'
#  'DEU_ANDROID_FEMALE_19_23_DEU_ANDROID_FEMALE_19_23']
# ['usa' 'ios' 'male' 26 34.0 '24_30'
#  'USA_IOS_MALE_24_30_USA_IOS_MALE_24_30']
# ['fra' 'ios' 'male' 26 34.0 '24_30'
#  'FRA_IOS_MALE_24_30_FRA_IOS_MALE_24_30']
# ['bra' 'ios' 'female' 27 34.0 '24_30'
#  'BRA_IOS_FEMALE_24_30_BRA_IOS_FEMALE_24_30']
# ['can' 'android' 'female' 43 34.0 '41_66'
#  'CAN_ANDROID_FEMALE_41_66_CAN_ANDROID_FEMALE_41_66']
# ['usa' 'ios' 'female' 22 34.0 '19_23'
#  'USA_IOS_FEMALE_19_23_USA_IOS_FEMALE_19_23']
# ['usa' 'ios' 'male' 20 34.0 '19_23'
#  'USA_IOS_MALE_19_23_USA_IOS_MALE_19_23']
# ['bra' 'ios' 'male' 19 34.0 '19_23'
#  'BRA_IOS_MALE_19_23_BRA_IOS_MALE_19_23']
# ['tur' 'ios' 'female' 23 34.0 '19_23'
#  'TUR_IOS_FEMALE_19_23_TUR_IOS_FEMALE_19_23']
# ['tur' 'ios' 'female' 25 34.0 '24_30'
#  'TUR_IOS_FEMALE_24_30_TUR_IOS_FEMALE_24_30']
# ['tur' 'ios' 'female' 26 34.0 '24_30'
#  'TUR_IOS_FEMALE_24_30_TUR_IOS_FEMALE_24_30']
# ['deu' 'ios' 'female' 22 34.0 '19_23'
#  'DEU_IOS_FEMALE_19_23_DEU_IOS_FEMALE_19_23']
# ['tur' 'ios' 'female' 51 34.0 '41_66'
#  'TUR_IOS_FEMALE_41_66_TUR_IOS_FEMALE_41_66']
# ['deu' 'android' 'male' 21 34.0 '19_23'
#  'DEU_ANDROID_MALE_19_23_DEU_ANDROID_MALE_19_23']
# ['bra' 'ios' 'female' 24 34.0 '24_30'
#  'BRA_IOS_FEMALE_24_30_BRA_IOS_FEMALE_24_30']
# ['usa' 'android' 'male' 16 34.0 '0_18'
#  'USA_ANDROID_MALE_0_18_USA_ANDROID_MALE_0_18']
# ['usa' 'ios' 'male' 53 34.0 '41_66'
#  'USA_IOS_MALE_41_66_USA_IOS_MALE_41_66']
# ['usa' 'android' 'female' 42 34.0 '41_66'
#  'USA_ANDROID_FEMALE_41_66_USA_ANDROID_FEMALE_41_66']
# ['fra' 'android' 'female' 35 34.0 '31_40'
#  'FRA_ANDROID_FEMALE_31_40_FRA_ANDROID_FEMALE_31_40']
# ['usa' 'android' 'male' 25 34.0 '24_30'
#  'USA_ANDROID_MALE_24_30_USA_ANDROID_MALE_24_30']
# ['usa' 'android' 'female' 25 34.0 '24_30'
#  'USA_ANDROID_FEMALE_24_30_USA_ANDROID_FEMALE_24_30']
# ['deu' 'ios' 'female' 23 34.0 '19_23'
#  'DEU_IOS_FEMALE_19_23_DEU_IOS_FEMALE_19_23']
# ['bra' 'ios' 'male' 24 33.86486486486486 '24_30'
#  'BRA_IOS_MALE_24_30_BRA_IOS_MALE_24_30']
# ['usa' 'ios' 'female' 15 33.857142857142854 '0_18'
#  'USA_IOS_FEMALE_0_18_USA_IOS_FEMALE_0_18']
# ['usa' 'android' 'female' 22 33.8 '19_23'
#  'USA_ANDROID_FEMALE_19_23_USA_ANDROID_FEMALE_19_23']
# ['bra' 'ios' 'male' 16 33.76190476190476 '0_18'
#  'BRA_IOS_MALE_0_18_BRA_IOS_MALE_0_18']
# ['deu' 'android' 'female' 17 33.73684210526316 '0_18'
#  'DEU_ANDROID_FEMALE_0_18_DEU_ANDROID_FEMALE_0_18']
# ['bra' 'android' 'female' 37 33.73684210526316 '31_40'
#  'BRA_ANDROID_FEMALE_31_40_BRA_ANDROID_FEMALE_31_40']
# ['usa' 'ios' 'male' 15 33.729729729729726 '0_18'
#  'USA_IOS_MALE_0_18_USA_IOS_MALE_0_18']
# ['can' 'ios' 'female' 15 33.705882352941174 '0_18'
#  'CAN_IOS_FEMALE_0_18_CAN_IOS_FEMALE_0_18']
# ['tur' 'android' 'female' 17 33.6875 '0_18'
#  'TUR_ANDROID_FEMALE_0_18_TUR_ANDROID_FEMALE_0_18']
# ['bra' 'ios' 'female' 16 33.6875 '0_18'
#  'BRA_IOS_FEMALE_0_18_BRA_IOS_FEMALE_0_18']
# ['fra' 'ios' 'female' 15 33.61538461538461 '0_18'
#  'FRA_IOS_FEMALE_0_18_FRA_IOS_FEMALE_0_18']
# ['bra' 'android' 'female' 45 33.61538461538461 '41_66'
#  'BRA_ANDROID_FEMALE_41_66_BRA_ANDROID_FEMALE_41_66']
# ['bra' 'ios' 'male' 44 33.54545454545455 '41_66'
#  'BRA_IOS_MALE_41_66_BRA_IOS_MALE_41_66']
# ['usa' 'android' 'male' 27 33.285714285714285 '24_30'
#  'USA_ANDROID_MALE_24_30_USA_ANDROID_MALE_24_30']
# ['bra' 'android' 'female' 26 33.166666666666664 '24_30'
#  'BRA_ANDROID_FEMALE_24_30_BRA_ANDROID_FEMALE_24_30']
# ['usa' 'android' 'female' 23 33.1025641025641 '19_23'
#  'USA_ANDROID_FEMALE_19_23_USA_ANDROID_FEMALE_19_23']
# ['bra' 'android' 'male' 18 33.054054054054056 '0_18'
#  'BRA_ANDROID_MALE_0_18_BRA_ANDROID_MALE_0_18']
# ['bra' 'ios' 'female' 46 33.0 '41_66'
#  'BRA_IOS_FEMALE_41_66_BRA_IOS_FEMALE_41_66']
# ['usa' 'android' 'male' 42 33.0 '41_66'
#  'USA_ANDROID_MALE_41_66_USA_ANDROID_MALE_41_66']
# ['fra' 'ios' 'female' 40 33.0 '31_40'
#  'FRA_IOS_FEMALE_31_40_FRA_IOS_FEMALE_31_40']
# ['fra' 'android' 'male' 25 33.0 '24_30'
#  'FRA_ANDROID_MALE_24_30_FRA_ANDROID_MALE_24_30']
# ['deu' 'ios' 'female' 32 33.0 '31_40'
#  'DEU_IOS_FEMALE_31_40_DEU_IOS_FEMALE_31_40']
# ['usa' 'ios' 'female' 18 32.91304347826087 '0_18'
#  'USA_IOS_FEMALE_0_18_USA_IOS_FEMALE_0_18']
# ['deu' 'android' 'male' 17 32.91304347826087 '0_18'
#  'DEU_ANDROID_MALE_0_18_DEU_ANDROID_MALE_0_18']
# ['usa' 'ios' 'male' 17 32.91304347826087 '0_18'
#  'USA_IOS_MALE_0_18_USA_IOS_MALE_0_18']
# ['bra' 'ios' 'female' 20 32.84615384615385 '19_23'
#  'BRA_IOS_FEMALE_19_23_BRA_IOS_FEMALE_19_23']
# ['tur' 'ios' 'male' 15 32.84615384615385 '0_18'
#  'TUR_IOS_MALE_0_18_TUR_IOS_MALE_0_18']
# ['usa' 'android' 'male' 19 32.80952380952381 '19_23'
#  'USA_ANDROID_MALE_19_23_USA_ANDROID_MALE_19_23']
# ['usa' 'ios' 'female' 23 32.80952380952381 '19_23'
#  'USA_IOS_FEMALE_19_23_USA_IOS_FEMALE_19_23']
# ['usa' 'ios' 'female' 24 32.75 '24_30'
#  'USA_IOS_FEMALE_24_30_USA_IOS_FEMALE_24_30']
# ['bra' 'ios' 'male' 18 32.68421052631579 '0_18'
#  'BRA_IOS_MALE_0_18_BRA_IOS_MALE_0_18']
# ['usa' 'android' 'female' 15 32.666666666666664 '0_18'
#  'USA_ANDROID_FEMALE_0_18_USA_ANDROID_FEMALE_0_18']
# ['fra' 'ios' 'female' 31 32.63636363636363 '31_40'
#  'FRA_IOS_FEMALE_31_40_FRA_IOS_FEMALE_31_40']
# ['bra' 'ios' 'female' 17 32.63636363636363 '0_18'
#  'BRA_IOS_FEMALE_0_18_BRA_IOS_FEMALE_0_18']
# ['tur' 'ios' 'female' 22 32.63636363636363 '19_23'
#  'TUR_IOS_FEMALE_19_23_TUR_IOS_FEMALE_19_23']
# ['bra' 'android' 'male' 27 32.63636363636363 '24_30'
#  'BRA_ANDROID_MALE_24_30_BRA_ANDROID_MALE_24_30']
# ['fra' 'ios' 'female' 18 32.57142857142857 '0_18'
#  'FRA_IOS_FEMALE_0_18_FRA_IOS_FEMALE_0_18']
# ['can' 'android' 'female' 19 32.529411764705884 '19_23'
#  'CAN_ANDROID_FEMALE_19_23_CAN_ANDROID_FEMALE_19_23']
# ['usa' 'android' 'female' 18 32.40425531914894 '0_18'
#  'USA_ANDROID_FEMALE_0_18_USA_ANDROID_FEMALE_0_18']
# ['deu' 'android' 'male' 18 32.333333333333336 '0_18'
#  'DEU_ANDROID_MALE_0_18_DEU_ANDROID_MALE_0_18']
# ['usa' 'android' 'male' 21 32.333333333333336 '19_23'
#  'USA_ANDROID_MALE_19_23_USA_ANDROID_MALE_19_23']
# ['deu' 'android' 'female' 34 32.333333333333336 '31_40'
#  'DEU_ANDROID_FEMALE_31_40_DEU_ANDROID_FEMALE_31_40']
# ['usa' 'android' 'female' 44 32.333333333333336 '41_66'
#  'USA_ANDROID_FEMALE_41_66_USA_ANDROID_FEMALE_41_66']
# ['fra' 'android' 'male' 32 32.333333333333336 '31_40'
#  'FRA_ANDROID_MALE_31_40_FRA_ANDROID_MALE_31_40']
# ['deu' 'android' 'female' 28 32.333333333333336 '24_30'
#  'DEU_ANDROID_FEMALE_24_30_DEU_ANDROID_FEMALE_24_30']
# ['fra' 'android' 'male' 46 32.333333333333336 '41_66'
#  'FRA_ANDROID_MALE_41_66_FRA_ANDROID_MALE_41_66']
# ['bra' 'ios' 'female' 28 32.333333333333336 '24_30'
#  'BRA_IOS_FEMALE_24_30_BRA_IOS_FEMALE_24_30']
# ['deu' 'android' 'male' 31 32.333333333333336 '31_40'
#  'DEU_ANDROID_MALE_31_40_DEU_ANDROID_MALE_31_40']
# ['tur' 'android' 'female' 20 32.333333333333336 '19_23'
#  'TUR_ANDROID_FEMALE_19_23_TUR_ANDROID_FEMALE_19_23']
# ['tur' 'android' 'female' 50 32.333333333333336 '41_66'
#  'TUR_ANDROID_FEMALE_41_66_TUR_ANDROID_FEMALE_41_66']
# ['bra' 'android' 'female' 41 32.333333333333336 '41_66'
#  'BRA_ANDROID_FEMALE_41_66_BRA_ANDROID_FEMALE_41_66']
# ['bra' 'ios' 'female' 35 32.333333333333336 '31_40'
#  'BRA_IOS_FEMALE_31_40_BRA_IOS_FEMALE_31_40']
# ['bra' 'android' 'female' 18 32.25581395348837 '0_18'
#  'BRA_ANDROID_FEMALE_0_18_BRA_ANDROID_FEMALE_0_18']
# ['usa' 'ios' 'male' 22 32.170731707317074 '19_23'
#  'USA_IOS_MALE_19_23_USA_IOS_MALE_19_23']
# ['fra' 'android' 'female' 23 32.125 '19_23'
#  'FRA_ANDROID_FEMALE_19_23_FRA_ANDROID_FEMALE_19_23']
# ['deu' 'android' 'female' 27 32.125 '24_30'
#  'DEU_ANDROID_FEMALE_24_30_DEU_ANDROID_FEMALE_24_30']
# ['deu' 'android' 'female' 15 32.0 '0_18'
#  'DEU_ANDROID_FEMALE_0_18_DEU_ANDROID_FEMALE_0_18']
# ['bra' 'android' 'female' 23 31.941176470588236 '19_23'
#  'BRA_ANDROID_FEMALE_19_23_BRA_ANDROID_FEMALE_19_23']
# ['usa' 'ios' 'male' 25 31.857142857142858 '24_30'
#  'USA_IOS_MALE_24_30_USA_IOS_MALE_24_30']
# ['bra' 'android' 'male' 36 31.857142857142858 '31_40'
#  'BRA_ANDROID_MALE_31_40_BRA_ANDROID_MALE_31_40']
# ['fra' 'android' 'female' 26 31.857142857142858 '24_30'
#  'FRA_ANDROID_FEMALE_24_30_FRA_ANDROID_FEMALE_24_30']
# ['usa' 'ios' 'male' 37 31.727272727272727 '31_40'
#  'USA_IOS_MALE_31_40_USA_IOS_MALE_31_40']
# ['can' 'ios' 'female' 29 31.727272727272727 '24_30'
#  'CAN_IOS_FEMALE_24_30_CAN_IOS_FEMALE_24_30']
# ['can' 'android' 'female' 20 31.5 '19_23'
#  'CAN_ANDROID_FEMALE_19_23_CAN_ANDROID_FEMALE_19_23']
# ['usa' 'ios' 'female' 27 31.5 '24_30'
#  'USA_IOS_FEMALE_24_30_USA_IOS_FEMALE_24_30']
# ['bra' 'android' 'male' 35 31.5 '31_40'
#  'BRA_ANDROID_MALE_31_40_BRA_ANDROID_MALE_31_40']
# ['usa' 'ios' 'female' 16 31.5 '0_18'
#  'USA_IOS_FEMALE_0_18_USA_IOS_FEMALE_0_18']
# ['deu' 'android' 'female' 44 31.5 '41_66'
#  'DEU_ANDROID_FEMALE_41_66_DEU_ANDROID_FEMALE_41_66']
# ['deu' 'ios' 'male' 32 31.352941176470587 '31_40'
#  'DEU_IOS_MALE_31_40_DEU_IOS_MALE_31_40']
# ['usa' 'android' 'female' 20 31.285714285714285 '19_23'
#  'USA_ANDROID_FEMALE_19_23_USA_ANDROID_FEMALE_19_23']
# ['deu' 'android' 'male' 19 31.22222222222222 '19_23'
#  'DEU_ANDROID_MALE_19_23_DEU_ANDROID_MALE_19_23']
# ['can' 'ios' 'male' 25 31.17391304347826 '24_30'
#  'CAN_IOS_MALE_24_30_CAN_IOS_MALE_24_30']
# ['tur' 'ios' 'male' 42 31.105263157894736 '41_66'
#  'TUR_IOS_MALE_41_66_TUR_IOS_MALE_41_66']
# ['can' 'ios' 'male' 57 31.0 '41_66'
#  'CAN_IOS_MALE_41_66_CAN_IOS_MALE_41_66']
# ['bra' 'android' 'male' 22 31.0 '19_23'
#  'BRA_ANDROID_MALE_19_23_BRA_ANDROID_MALE_19_23']
# ['deu' 'android' 'female' 21 31.0 '19_23'
#  'DEU_ANDROID_FEMALE_19_23_DEU_ANDROID_FEMALE_19_23']
# ['bra' 'ios' 'male' 21 31.0 '19_23'
#  'BRA_IOS_MALE_19_23_BRA_IOS_MALE_19_23']
# ['bra' 'android' 'female' 20 31.0 '19_23'
#  'BRA_ANDROID_FEMALE_19_23_BRA_ANDROID_FEMALE_19_23']
# ['tur' 'android' 'female' 19 31.0 '19_23'
#  'TUR_ANDROID_FEMALE_19_23_TUR_ANDROID_FEMALE_19_23']
# ['deu' 'ios' 'male' 30 31.0 '24_30'
#  'DEU_IOS_MALE_24_30_DEU_IOS_MALE_24_30']
# ['usa' 'ios' 'female' 34 30.875 '31_40'
#  'USA_IOS_FEMALE_31_40_USA_IOS_FEMALE_31_40']
# ['usa' 'android' 'female' 26 30.77777777777778 '24_30'
#  'USA_ANDROID_FEMALE_24_30_USA_ANDROID_FEMALE_24_30']
# ['deu' 'ios' 'female' 15 30.666666666666668 '0_18'
#  'DEU_IOS_FEMALE_0_18_DEU_IOS_FEMALE_0_18']
# ['fra' 'ios' 'male' 16 30.666666666666668 '0_18'
#  'FRA_IOS_MALE_0_18_FRA_IOS_MALE_0_18']
# ['bra' 'android' 'male' 25 30.428571428571427 '24_30'
#  'BRA_ANDROID_MALE_24_30_BRA_ANDROID_MALE_24_30']
# ['bra' 'ios' 'female' 29 30.428571428571427 '24_30'
#  'BRA_IOS_FEMALE_24_30_BRA_IOS_FEMALE_24_30']
# ['bra' 'ios' 'male' 66 30.428571428571427 '41_66'
#  'BRA_IOS_MALE_41_66_BRA_IOS_MALE_41_66']
# ['fra' 'ios' 'female' 28 30.428571428571427 '24_30'
#  'FRA_IOS_FEMALE_24_30_FRA_IOS_FEMALE_24_30']
# ['usa' 'ios' 'female' 50 30.304347826086957 '41_66'
#  'USA_IOS_FEMALE_41_66_USA_IOS_FEMALE_41_66']
# ['usa' 'ios' 'male' 33 30.304347826086957 '31_40'
#  'USA_IOS_MALE_31_40_USA_IOS_MALE_31_40']
# ['usa' 'ios' 'male' 42 30.25 '41_66'
#  'USA_IOS_MALE_41_66_USA_IOS_MALE_41_66']
# ['fra' 'android' 'male' 15 30.25 '0_18'
#  'FRA_ANDROID_MALE_0_18_FRA_ANDROID_MALE_0_18']
# ['tur' 'ios' 'female' 17 30.176470588235293 '0_18'
#  'TUR_IOS_FEMALE_0_18_TUR_IOS_FEMALE_0_18']
# ['bra' 'ios' 'male' 42 30.11111111111111 '41_66'
#  'BRA_IOS_MALE_41_66_BRA_IOS_MALE_41_66']
# ['usa' 'android' 'female' 24 30.05263157894737 '24_30'
#  'USA_ANDROID_FEMALE_24_30_USA_ANDROID_FEMALE_24_30']
# ['can' 'android' 'male' 24 29.76923076923077 '24_30'
#  'CAN_ANDROID_MALE_24_30_CAN_ANDROID_MALE_24_30']
# ['bra' 'ios' 'female' 23 29.76923076923077 '19_23'
#  'BRA_IOS_FEMALE_19_23_BRA_IOS_FEMALE_19_23']
# ['bra' 'android' 'male' 29 29.714285714285715 '24_30'
#  'BRA_ANDROID_MALE_24_30_BRA_ANDROID_MALE_24_30']
# ['can' 'android' 'female' 16 29.689655172413794 '0_18'
#  'CAN_ANDROID_FEMALE_0_18_CAN_ANDROID_FEMALE_0_18']
# ['bra' 'android' 'male' 16 29.666666666666668 '0_18'
#  'BRA_ANDROID_MALE_0_18_BRA_ANDROID_MALE_0_18']
# ['usa' 'ios' 'female' 35 29.625 '31_40'
#  'USA_IOS_FEMALE_31_40_USA_IOS_FEMALE_31_40']
# ['fra' 'ios' 'male' 15 29.0 '0_18' 'FRA_IOS_MALE_0_18_FRA_IOS_MALE_0_18']
# ['fra' 'ios' 'male' 27 29.0 '24_30'
#  'FRA_IOS_MALE_24_30_FRA_IOS_MALE_24_30']
# ['bra' 'android' 'male' 53 29.0 '41_66'
#  'BRA_ANDROID_MALE_41_66_BRA_ANDROID_MALE_41_66']
# ['fra' 'ios' 'male' 38 29.0 '31_40'
#  'FRA_IOS_MALE_31_40_FRA_IOS_MALE_31_40']
# ['can' 'ios' 'male' 32 29.0 '31_40'
#  'CAN_IOS_MALE_31_40_CAN_IOS_MALE_31_40']
# ['usa' 'ios' 'female' 42 29.0 '41_66'
#  'USA_IOS_FEMALE_41_66_USA_IOS_FEMALE_41_66']
# ['can' 'ios' 'female' 16 29.0 '0_18'
#  'CAN_IOS_FEMALE_0_18_CAN_IOS_FEMALE_0_18']
# ['deu' 'ios' 'male' 23 29.0 '19_23'
#  'DEU_IOS_MALE_19_23_DEU_IOS_MALE_19_23']
# ['deu' 'ios' 'female' 24 29.0 '24_30'
#  'DEU_IOS_FEMALE_24_30_DEU_IOS_FEMALE_24_30']
# ['deu' 'android' 'male' 32 29.0 '31_40'
#  'DEU_ANDROID_MALE_31_40_DEU_ANDROID_MALE_31_40']
# ['deu' 'android' 'male' 24 29.0 '24_30'
#  'DEU_ANDROID_MALE_24_30_DEU_ANDROID_MALE_24_30']
# ['deu' 'android' 'female' 33 29.0 '31_40'
#  'DEU_ANDROID_FEMALE_31_40_DEU_ANDROID_FEMALE_31_40']
# ['usa' 'ios' 'male' 55 29.0 '41_66'
#  'USA_IOS_MALE_41_66_USA_IOS_MALE_41_66']
# ['tur' 'android' 'female' 56 29.0 '41_66'
#  'TUR_ANDROID_FEMALE_41_66_TUR_ANDROID_FEMALE_41_66']
# ['bra' 'ios' 'male' 31 29.0 '31_40'
#  'BRA_IOS_MALE_31_40_BRA_IOS_MALE_31_40']
# ['usa' 'android' 'male' 38 29.0 '31_40'
#  'USA_ANDROID_MALE_31_40_USA_ANDROID_MALE_31_40']
# ['usa' 'android' 'male' 57 29.0 '41_66'
#  'USA_ANDROID_MALE_41_66_USA_ANDROID_MALE_41_66']
# ['usa' 'android' 'female' 27 29.0 '24_30'
#  'USA_ANDROID_FEMALE_24_30_USA_ANDROID_FEMALE_24_30']
# ['usa' 'android' 'male' 34 29.0 '31_40'
#  'USA_ANDROID_MALE_31_40_USA_ANDROID_MALE_31_40']
# ['usa' 'android' 'male' 37 29.0 '31_40'
#  'USA_ANDROID_MALE_31_40_USA_ANDROID_MALE_31_40']
# ['bra' 'ios' 'male' 37 29.0 '31_40'
#  'BRA_IOS_MALE_31_40_BRA_IOS_MALE_31_40']
# ['usa' 'android' 'female' 30 29.0 '24_30'
#  'USA_ANDROID_FEMALE_24_30_USA_ANDROID_FEMALE_24_30']
# ['tur' 'android' 'male' 36 29.0 '31_40'
#  'TUR_ANDROID_MALE_31_40_TUR_ANDROID_MALE_31_40']
# ['tur' 'ios' 'female' 16 29.0 '0_18'
#  'TUR_IOS_FEMALE_0_18_TUR_IOS_FEMALE_0_18']
# ['bra' 'android' 'male' 28 28.23076923076923 '24_30'
#  'BRA_ANDROID_MALE_24_30_BRA_ANDROID_MALE_24_30']
# ['usa' 'android' 'female' 32 28.166666666666668 '31_40'
#  'USA_ANDROID_FEMALE_31_40_USA_ANDROID_FEMALE_31_40']
# ['usa' 'android' 'female' 34 28.0 '31_40'
#  'USA_ANDROID_FEMALE_31_40_USA_ANDROID_FEMALE_31_40']
# ['deu' 'android' 'female' 41 27.75 '41_66'
#  'DEU_ANDROID_FEMALE_41_66_DEU_ANDROID_FEMALE_41_66']
# ['fra' 'ios' 'female' 16 27.75 '0_18'
#  'FRA_IOS_FEMALE_0_18_FRA_IOS_FEMALE_0_18']
# ['bra' 'ios' 'female' 31 27.571428571428573 '31_40'
#  'BRA_IOS_FEMALE_31_40_BRA_IOS_FEMALE_31_40']
# ['tur' 'ios' 'male' 19 27.333333333333332 '19_23'
#  'TUR_IOS_MALE_19_23_TUR_IOS_MALE_19_23']
# ['fra' 'android' 'female' 19 27.333333333333332 '19_23'
#  'FRA_ANDROID_FEMALE_19_23_FRA_ANDROID_FEMALE_19_23']
# ['deu' 'android' 'female' 16 27.0 '0_18'
#  'DEU_ANDROID_FEMALE_0_18_DEU_ANDROID_FEMALE_0_18']
# ['bra' 'android' 'female' 27 26.142857142857142 '24_30'
#  'BRA_ANDROID_FEMALE_24_30_BRA_ANDROID_FEMALE_24_30']
# ['usa' 'android' 'male' 24 26.058823529411764 '24_30'
#  'USA_ANDROID_MALE_24_30_USA_ANDROID_MALE_24_30']
# ['can' 'android' 'female' 15 25.666666666666668 '0_18'
#  'CAN_ANDROID_FEMALE_0_18_CAN_ANDROID_FEMALE_0_18']
# ['tur' 'ios' 'female' 38 25.666666666666668 '31_40'
#  'TUR_IOS_FEMALE_31_40_TUR_IOS_FEMALE_31_40']
# ['fra' 'android' 'male' 21 25.666666666666668 '19_23'
#  'FRA_ANDROID_MALE_19_23_FRA_ANDROID_MALE_19_23']
# ['usa' 'android' 'male' 65 25.666666666666668 '41_66'
#  'USA_ANDROID_MALE_41_66_USA_ANDROID_MALE_41_66']
# ['fra' 'ios' 'female' 25 25.0 '24_30'
#  'FRA_IOS_FEMALE_24_30_FRA_IOS_FEMALE_24_30']
# ['bra' 'android' 'female' 34 24.0 '31_40'
#  'BRA_ANDROID_FEMALE_31_40_BRA_ANDROID_FEMALE_31_40']
# ['tur' 'android' 'female' 29 24.0 '24_30'
#  'TUR_ANDROID_FEMALE_24_30_TUR_ANDROID_FEMALE_24_30']
# ['usa' 'ios' 'male' 36 24.0 '31_40'
#  'USA_IOS_MALE_31_40_USA_IOS_MALE_31_40']
# ['usa' 'ios' 'male' 29 24.0 '24_30'
#  'USA_IOS_MALE_24_30_USA_IOS_MALE_24_30']
# ['bra' 'android' 'female' 28 22.333333333333332 '24_30'
#  'BRA_ANDROID_FEMALE_24_30_BRA_ANDROID_FEMALE_24_30']
# ['tur' 'ios' 'male' 21 22.333333333333332 '19_23'
#  'TUR_IOS_MALE_19_23_TUR_IOS_MALE_19_23']
# ['usa' 'android' 'male' 29 22.333333333333332 '24_30'
#  'USA_ANDROID_MALE_24_30_USA_ANDROID_MALE_24_30']
# ['bra' 'ios' 'male' 36 22.333333333333332 '31_40'
#  'BRA_IOS_MALE_31_40_BRA_IOS_MALE_31_40']
# ['bra' 'android' 'male' 23 21.5 '19_23'
#  'BRA_ANDROID_MALE_19_23_BRA_ANDROID_MALE_19_23']
# ['tur' 'android' 'male' 21 19.0 '19_23'
#  'TUR_ANDROID_MALE_19_23_TUR_ANDROID_MALE_19_23']
# ['tur' 'ios' 'male' 47 19.0 '41_66'
#  'TUR_IOS_MALE_41_66_TUR_IOS_MALE_41_66']
# ['bra' 'ios' 'female' 34 19.0 '31_40'
#  'BRA_IOS_FEMALE_31_40_BRA_IOS_FEMALE_31_40']
# ['bra' 'ios' 'male' 47 19.0 '41_66'
#  'BRA_IOS_MALE_41_66_BRA_IOS_MALE_41_66']
# ['usa' 'ios' 'female' 38 19.0 '31_40'
#  'USA_IOS_FEMALE_31_40_USA_IOS_FEMALE_31_40']
# ['usa' 'ios' 'female' 30 19.0 '24_30'
#  'USA_IOS_FEMALE_24_30_USA_IOS_FEMALE_24_30']
# ['can' 'android' 'female' 27 19.0 '24_30'
#  'CAN_ANDROID_FEMALE_24_30_CAN_ANDROID_FEMALE_24_30']
# ['fra' 'android' 'male' 18 19.0 '0_18'
#  'FRA_ANDROID_MALE_0_18_FRA_ANDROID_MALE_0_18']
# ['deu' 'android' 'male' 26 9.0 '24_30'
#  'DEU_ANDROID_MALE_24_30_DEU_ANDROID_MALE_24_30']
# ['BRA', 'ANDROID', 'MALE', '41', '66']
# ['USA', 'ANDROID', 'MALE', '31', '40']
# ['FRA', 'ANDROID', 'FEMALE', '24', '30']
# ['USA', 'IOS', 'MALE', '31', '40']
# ['DEU', 'ANDROID', 'FEMALE', '31', '40']
# ['DEU', 'ANDROID', 'FEMALE', '41', '66']
# ['DEU', 'IOS', 'MALE', '19', '23']
# ['USA', 'ANDROID', 'FEMALE', '41', '66']
# ['FRA', 'IOS', 'MALE', '19', '23']
# ['USA', 'IOS', 'MALE', '41', '66']
# ['DEU', 'ANDROID', 'MALE', '0', '18']
# ['BRA', 'ANDROID', 'FEMALE', '24', '30']
# ['USA', 'ANDROID', 'FEMALE', '41', '66']
# ['TUR', 'IOS', 'MALE', '24', '30']
# ['DEU', 'ANDROID', 'MALE', '31', '40']
# ['TUR', 'IOS', 'FEMALE', '0', '18']
# ['BRA', 'ANDROID', 'FEMALE', '41', '66']
# ['BRA', 'IOS', 'FEMALE', '19', '23']
# ['TUR', 'ANDROID', 'FEMALE', '31', '40']
# ['BRA', 'ANDROID', 'FEMALE', '31', '40']
# ['TUR', 'IOS', 'MALE', '31', '40']
# ['TUR', 'ANDROID', 'MALE', '0', '18']
# ['USA', 'IOS', 'MALE', '24', '30']
# ['BRA', 'IOS', 'MALE', '41', '66']
# ['DEU', 'ANDROID', 'MALE', '19', '23']
# ['USA', 'IOS', 'MALE', '24', '30']
# ['TUR', 'ANDROID', 'FEMALE', '0', '18']
# ['USA', 'ANDROID', 'MALE', '41', '66']
# ['TUR', 'ANDROID', 'MALE', '24', '30']
# ['USA', 'IOS', 'FEMALE', '41', '66']
# ['FRA', 'ANDROID', 'MALE', '19', '23']
# ['USA', 'IOS', 'MALE', '31', '40']
# ['TUR', 'ANDROID', 'FEMALE', '0', '18']
# ['FRA', 'IOS', 'MALE', '0', '18']
# ['TUR', 'IOS', 'FEMALE', '19', '23']
# ['TUR', 'ANDROID', 'FEMALE', '31', '40']
# ['TUR', 'ANDROID', 'MALE', '24', '30']
# ['FRA', 'ANDROID', 'MALE', '19', '23']
# ['BRA', 'ANDROID', 'MALE', '24', '30']
# ['CAN', 'ANDROID', 'MALE', '24', '30']
# ['CAN', 'ANDROID', 'MALE', '19', '23']
# ['USA', 'ANDROID', 'MALE', '41', '66']
# ['TUR', 'ANDROID', 'MALE', '24', '30']
# ['BRA', 'ANDROID', 'MALE', '31', '40']
# ['BRA', 'ANDROID', 'MALE', '0', '18']
# ['USA', 'IOS', 'FEMALE', '19', '23']
# ['TUR', 'ANDROID', 'MALE', '41', '66']
# ['BRA', 'IOS', 'FEMALE', '19', '23']
# ['USA', 'IOS', 'MALE', '41', '66']
# ['BRA', 'IOS', 'FEMALE', '24', '30']
# ['DEU', 'ANDROID', 'FEMALE', '31', '40']
# ['DEU', 'IOS', 'MALE', '0', '18']
# ['FRA', 'ANDROID', 'FEMALE', '19', '23']
# ['FRA', 'ANDROID', 'MALE', '31', '40']
# ['TUR', 'IOS', 'FEMALE', '31', '40']
# ['FRA', 'IOS', 'MALE', '41', '66']
# ['BRA', 'ANDROID', 'FEMALE', '31', '40']
# ['TUR', 'IOS', 'MALE', '0', '18']
# ['BRA', 'IOS', 'FEMALE', '41', '66']
# ['TUR', 'ANDROID', 'MALE', '0', '18']
# ['TUR', 'ANDROID', 'FEMALE', '41', '66']
# ['BRA', 'ANDROID', 'FEMALE', '0', '18']
# ['USA', 'IOS', 'MALE', '19', '23']
# ['USA', 'IOS', 'FEMALE', '0', '18']
# ['FRA', 'IOS', 'MALE', '31', '40']
# ['TUR', 'ANDROID', 'MALE', '0', '18']
# ['DEU', 'ANDROID', 'MALE', '31', '40']
# ['USA', 'IOS', 'FEMALE', '24', '30']
# ['DEU', 'IOS', 'FEMALE', '0', '18']
# ['CAN', 'IOS', 'MALE', '0', '18']
# ['CAN', 'ANDROID', 'MALE', '41', '66']
# ['BRA', 'ANDROID', 'FEMALE', '24', '30']
# ['TUR', 'ANDROID', 'FEMALE', '24', '30']
# ['CAN', 'IOS', 'MALE', '0', '18']
# ['BRA', 'IOS', 'MALE', '31', '40']
# ['FRA', 'ANDROID', 'FEMALE', '0', '18']
# ['DEU', 'IOS', 'FEMALE', '0', '18']
# ['CAN', 'ANDROID', 'FEMALE', '0', '18']
# ['TUR', 'IOS', 'FEMALE', '19', '23']
# ['DEU', 'ANDROID', 'MALE', '19', '23']
# ['BRA', 'ANDROID', 'FEMALE', '19', '23']
# ['USA', 'ANDROID', 'FEMALE', '31', '40']
# ['BRA', 'IOS', 'MALE', '19', '23']
# ['BRA', 'ANDROID', 'MALE', '0', '18']
# ['BRA', 'ANDROID', 'MALE', '24', '30']
# ['USA', 'ANDROID', 'MALE', '24', '30']
# ['TUR', 'ANDROID', 'FEMALE', '19', '23']
# ['DEU', 'IOS', 'MALE', '41', '66']
# ['BRA', 'ANDROID', 'FEMALE', '41', '66']
# ['BRA', 'IOS', 'MALE', '0', '18']
# ['USA', 'IOS', 'FEMALE', '24', '30']
# ['BRA', 'IOS', 'FEMALE', '0', '18']
# ['BRA', 'IOS', 'MALE', '31', '40']
# ['FRA', 'ANDROID', 'FEMALE', '0', '18']
# ['USA', 'ANDROID', 'MALE', '19', '23']
# ['BRA', 'IOS', 'FEMALE', '0', '18']
# ['BRA', 'ANDROID', 'MALE', '41', '66']
# ['BRA', 'ANDROID', 'FEMALE', '24', '30']
# ['USA', 'ANDROID', 'MALE', '24', '30']
# ['TUR', 'ANDROID', 'FEMALE', '41', '66']
# ['USA', 'IOS', 'FEMALE', '24', '30']
# ['DEU', 'IOS', 'FEMALE', '24', '30']
# ['CAN', 'ANDROID', 'MALE', '0', '18']
# ['BRA', 'ANDROID', 'FEMALE', '0', '18']
# ['TUR', 'ANDROID', 'MALE', '24', '30']
# ['USA', 'ANDROID', 'MALE', '41', '66']
# ['USA', 'IOS', 'FEMALE', '19', '23']
# ['USA', 'ANDROID', 'FEMALE', '19', '23']
# ['FRA', 'IOS', 'MALE', '19', '23']
# ['FRA', 'ANDROID', 'MALE', '41', '66']
# ['BRA', 'ANDROID', 'MALE', '41', '66']
# ['TUR', 'ANDROID', 'MALE', '19', '23']
# ['BRA', 'ANDROID', 'FEMALE', '24', '30']
# ['USA', 'ANDROID', 'FEMALE', '31', '40']
# ['USA', 'IOS', 'FEMALE', '24', '30']
# ['BRA', 'ANDROID', 'FEMALE', '0', '18']
# ['TUR', 'IOS', 'FEMALE', '19', '23']
# ['DEU', 'IOS', 'FEMALE', '0', '18']
# ['USA', 'ANDROID', 'MALE', '41', '66']
# ['BRA', 'ANDROID', 'MALE', '19', '23']
# ['DEU', 'ANDROID', 'MALE', '31', '40']
# ['BRA', 'IOS', 'FEMALE', '31', '40']
# ['BRA', 'IOS', 'FEMALE', '41', '66']
# ['BRA', 'ANDROID', 'MALE', '24', '30']
# ['DEU', 'ANDROID', 'FEMALE', '24', '30']
# ['BRA', 'IOS', 'MALE', '0', '18']
# ['BRA', 'ANDROID', 'MALE', '19', '23']
# ['USA', 'ANDROID', 'FEMALE', '41', '66']
# ['BRA', 'ANDROID', 'MALE', '19', '23']
# ['BRA', 'ANDROID', 'FEMALE', '19', '23']
# ['USA', 'ANDROID', 'MALE', '0', '18']
# ['BRA', 'IOS', 'FEMALE', '31', '40']
# ['USA', 'IOS', 'MALE', '24', '30']
# ['BRA', 'ANDROID', 'FEMALE', '31', '40']
# ['USA', 'IOS', 'FEMALE', '19', '23']
# ['USA', 'ANDROID', 'FEMALE', '31', '40']
# ['FRA', 'IOS', 'MALE', '19', '23']
# ['DEU', 'ANDROID', 'FEMALE', '19', '23']
# ['CAN', 'IOS', 'MALE', '0', '18']
# ['DEU', 'IOS', 'MALE', '0', '18']
# ['USA', 'IOS', 'FEMALE', '41', '66']
# ['DEU', 'IOS', 'MALE', '24', '30']
# ['BRA', 'ANDROID', 'FEMALE', '19', '23']
# ['USA', 'ANDROID', 'FEMALE', '0', '18']
# ['BRA', 'IOS', 'MALE', '19', '23']
# ['USA', 'ANDROID', 'MALE', '19', '23']
# ['TUR', 'IOS', 'MALE', '0', '18']
# ['USA', 'ANDROID', 'FEMALE', '24', '30']
# ['USA', 'IOS', 'MALE', '0', '18']
# ['BRA', 'IOS', 'MALE', '31', '40']
# ['USA', 'ANDROID', 'MALE', '19', '23']
# ['USA', 'ANDROID', 'MALE', '31', '40']
# ['USA', 'ANDROID', 'MALE', '31', '40']
# ['USA', 'IOS', 'FEMALE', '41', '66']
# ['USA', 'ANDROID', 'MALE', '0', '18']
# ['FRA', 'ANDROID', 'FEMALE', '0', '18']
# ['USA', 'ANDROID', 'FEMALE', '0', '18']
# ['USA', 'IOS', 'MALE', '0', '18']
# ['BRA', 'ANDROID', 'FEMALE', '31', '40']
# ['USA', 'IOS', 'FEMALE', '31', '40']
# ['TUR', 'ANDROID', 'FEMALE', '0', '18']
# ['DEU', 'ANDROID', 'FEMALE', '24', '30']
# ['USA', 'ANDROID', 'MALE', '0', '18']
# ['USA', 'ANDROID', 'MALE', '24', '30']
# ['BRA', 'IOS', 'FEMALE', '24', '30']
# ['USA', 'ANDROID', 'FEMALE', '19', '23']
# ['BRA', 'IOS', 'FEMALE', '41', '66']
# ['DEU', 'ANDROID', 'FEMALE', '19', '23']
# ['USA', 'IOS', 'MALE', '24', '30']
# ['FRA', 'IOS', 'MALE', '24', '30']
# ['BRA', 'IOS', 'FEMALE', '24', '30']
# ['CAN', 'ANDROID', 'FEMALE', '41', '66']
# ['USA', 'IOS', 'FEMALE', '19', '23']
# ['USA', 'IOS', 'MALE', '19', '23']
# ['BRA', 'IOS', 'MALE', '19', '23']
# ['TUR', 'IOS', 'FEMALE', '19', '23']
# ['TUR', 'IOS', 'FEMALE', '24', '30']
# ['TUR', 'IOS', 'FEMALE', '24', '30']
# ['DEU', 'IOS', 'FEMALE', '19', '23']
# ['TUR', 'IOS', 'FEMALE', '41', '66']
# ['DEU', 'ANDROID', 'MALE', '19', '23']
# ['BRA', 'IOS', 'FEMALE', '24', '30']
# ['USA', 'ANDROID', 'MALE', '0', '18']
# ['USA', 'IOS', 'MALE', '41', '66']
# ['USA', 'ANDROID', 'FEMALE', '41', '66']
# ['FRA', 'ANDROID', 'FEMALE', '31', '40']
# ['USA', 'ANDROID', 'MALE', '24', '30']
# ['USA', 'ANDROID', 'FEMALE', '24', '30']
# ['DEU', 'IOS', 'FEMALE', '19', '23']
# ['BRA', 'IOS', 'MALE', '24', '30']
# ['USA', 'IOS', 'FEMALE', '0', '18']
# ['USA', 'ANDROID', 'FEMALE', '19', '23']
# ['BRA', 'IOS', 'MALE', '0', '18']
# ['DEU', 'ANDROID', 'FEMALE', '0', '18']
# ['BRA', 'ANDROID', 'FEMALE', '31', '40']
# ['USA', 'IOS', 'MALE', '0', '18']
# ['CAN', 'IOS', 'FEMALE', '0', '18']
# ['TUR', 'ANDROID', 'FEMALE', '0', '18']
# ['BRA', 'IOS', 'FEMALE', '0', '18']
# ['FRA', 'IOS', 'FEMALE', '0', '18']
# ['BRA', 'ANDROID', 'FEMALE', '41', '66']
# ['BRA', 'IOS', 'MALE', '41', '66']
# ['USA', 'ANDROID', 'MALE', '24', '30']
# ['BRA', 'ANDROID', 'FEMALE', '24', '30']
# ['USA', 'ANDROID', 'FEMALE', '19', '23']
# ['BRA', 'ANDROID', 'MALE', '0', '18']
# ['BRA', 'IOS', 'FEMALE', '41', '66']
# ['USA', 'ANDROID', 'MALE', '41', '66']
# ['FRA', 'IOS', 'FEMALE', '31', '40']
# ['FRA', 'ANDROID', 'MALE', '24', '30']
# ['DEU', 'IOS', 'FEMALE', '31', '40']
# ['USA', 'IOS', 'FEMALE', '0', '18']
# ['DEU', 'ANDROID', 'MALE', '0', '18']
# ['USA', 'IOS', 'MALE', '0', '18']
# ['BRA', 'IOS', 'FEMALE', '19', '23']
# ['TUR', 'IOS', 'MALE', '0', '18']
# ['USA', 'ANDROID', 'MALE', '19', '23']
# ['USA', 'IOS', 'FEMALE', '19', '23']
# ['USA', 'IOS', 'FEMALE', '24', '30']
# ['BRA', 'IOS', 'MALE', '0', '18']
# ['USA', 'ANDROID', 'FEMALE', '0', '18']
# ['FRA', 'IOS', 'FEMALE', '31', '40']
# ['BRA', 'IOS', 'FEMALE', '0', '18']
# ['TUR', 'IOS', 'FEMALE', '19', '23']
# ['BRA', 'ANDROID', 'MALE', '24', '30']
# ['FRA', 'IOS', 'FEMALE', '0', '18']
# ['CAN', 'ANDROID', 'FEMALE', '19', '23']
# ['USA', 'ANDROID', 'FEMALE', '0', '18']
# ['DEU', 'ANDROID', 'MALE', '0', '18']
# ['USA', 'ANDROID', 'MALE', '19', '23']
# ['DEU', 'ANDROID', 'FEMALE', '31', '40']
# ['USA', 'ANDROID', 'FEMALE', '41', '66']
# ['FRA', 'ANDROID', 'MALE', '31', '40']
# ['DEU', 'ANDROID', 'FEMALE', '24', '30']
# ['FRA', 'ANDROID', 'MALE', '41', '66']
# ['BRA', 'IOS', 'FEMALE', '24', '30']
# ['DEU', 'ANDROID', 'MALE', '31', '40']
# ['TUR', 'ANDROID', 'FEMALE', '19', '23']
# ['TUR', 'ANDROID', 'FEMALE', '41', '66']
# ['BRA', 'ANDROID', 'FEMALE', '41', '66']
# ['BRA', 'IOS', 'FEMALE', '31', '40']
# ['BRA', 'ANDROID', 'FEMALE', '0', '18']
# ['USA', 'IOS', 'MALE', '19', '23']
# ['FRA', 'ANDROID', 'FEMALE', '19', '23']
# ['DEU', 'ANDROID', 'FEMALE', '24', '30']
# ['DEU', 'ANDROID', 'FEMALE', '0', '18']
# ['BRA', 'ANDROID', 'FEMALE', '19', '23']
# ['USA', 'IOS', 'MALE', '24', '30']
# ['BRA', 'ANDROID', 'MALE', '31', '40']
# ['FRA', 'ANDROID', 'FEMALE', '24', '30']
# ['USA', 'IOS', 'MALE', '31', '40']
# ['CAN', 'IOS', 'FEMALE', '24', '30']
# ['CAN', 'ANDROID', 'FEMALE', '19', '23']
# ['USA', 'IOS', 'FEMALE', '24', '30']
# ['BRA', 'ANDROID', 'MALE', '31', '40']
# ['USA', 'IOS', 'FEMALE', '0', '18']
# ['DEU', 'ANDROID', 'FEMALE', '41', '66']
# ['DEU', 'IOS', 'MALE', '31', '40']
# ['USA', 'ANDROID', 'FEMALE', '19', '23']
# ['DEU', 'ANDROID', 'MALE', '19', '23']
# ['CAN', 'IOS', 'MALE', '24', '30']
# ['TUR', 'IOS', 'MALE', '41', '66']
# ['CAN', 'IOS', 'MALE', '41', '66']
# ['BRA', 'ANDROID', 'MALE', '19', '23']
# ['DEU', 'ANDROID', 'FEMALE', '19', '23']
# ['BRA', 'IOS', 'MALE', '19', '23']
# ['BRA', 'ANDROID', 'FEMALE', '19', '23']
# ['TUR', 'ANDROID', 'FEMALE', '19', '23']
# ['DEU', 'IOS', 'MALE', '24', '30']
# ['USA', 'IOS', 'FEMALE', '31', '40']
# ['USA', 'ANDROID', 'FEMALE', '24', '30']
# ['DEU', 'IOS', 'FEMALE', '0', '18']
# ['FRA', 'IOS', 'MALE', '0', '18']
# ['BRA', 'ANDROID', 'MALE', '24', '30']
# ['BRA', 'IOS', 'FEMALE', '24', '30']
# ['BRA', 'IOS', 'MALE', '41', '66']
# ['FRA', 'IOS', 'FEMALE', '24', '30']
# ['USA', 'IOS', 'FEMALE', '41', '66']
# ['USA', 'IOS', 'MALE', '31', '40']
# ['USA', 'IOS', 'MALE', '41', '66']
# ['FRA', 'ANDROID', 'MALE', '0', '18']
# ['TUR', 'IOS', 'FEMALE', '0', '18']
# ['BRA', 'IOS', 'MALE', '41', '66']
# ['USA', 'ANDROID', 'FEMALE', '24', '30']
# ['CAN', 'ANDROID', 'MALE', '24', '30']
# ['BRA', 'IOS', 'FEMALE', '19', '23']
# ['BRA', 'ANDROID', 'MALE', '24', '30']
# ['CAN', 'ANDROID', 'FEMALE', '0', '18']
# ['BRA', 'ANDROID', 'MALE', '0', '18']
# ['USA', 'IOS', 'FEMALE', '31', '40']
# ['FRA', 'IOS', 'MALE', '0', '18']
# ['FRA', 'IOS', 'MALE', '24', '30']
# ['BRA', 'ANDROID', 'MALE', '41', '66']
# ['FRA', 'IOS', 'MALE', '31', '40']
# ['CAN', 'IOS', 'MALE', '31', '40']
# ['USA', 'IOS', 'FEMALE', '41', '66']
# ['CAN', 'IOS', 'FEMALE', '0', '18']
# ['DEU', 'IOS', 'MALE', '19', '23']
# ['DEU', 'IOS', 'FEMALE', '24', '30']
# ['DEU', 'ANDROID', 'MALE', '31', '40']
# ['DEU', 'ANDROID', 'MALE', '24', '30']
# ['DEU', 'ANDROID', 'FEMALE', '31', '40']
# ['USA', 'IOS', 'MALE', '41', '66']
# ['TUR', 'ANDROID', 'FEMALE', '41', '66']
# ['BRA', 'IOS', 'MALE', '31', '40']
# ['USA', 'ANDROID', 'MALE', '31', '40']
# ['USA', 'ANDROID', 'MALE', '41', '66']
# ['USA', 'ANDROID', 'FEMALE', '24', '30']
# ['USA', 'ANDROID', 'MALE', '31', '40']
# ['USA', 'ANDROID', 'MALE', '31', '40']
# ['BRA', 'IOS', 'MALE', '31', '40']
# ['USA', 'ANDROID', 'FEMALE', '24', '30']
# ['TUR', 'ANDROID', 'MALE', '31', '40']
# ['TUR', 'IOS', 'FEMALE', '0', '18']
# ['BRA', 'ANDROID', 'MALE', '24', '30']
# ['USA', 'ANDROID', 'FEMALE', '31', '40']
# ['USA', 'ANDROID', 'FEMALE', '31', '40']
# ['DEU', 'ANDROID', 'FEMALE', '41', '66']
# ['FRA', 'IOS', 'FEMALE', '0', '18']
# ['BRA', 'IOS', 'FEMALE', '31', '40']
# ['TUR', 'IOS', 'MALE', '19', '23']
# ['FRA', 'ANDROID', 'FEMALE', '19', '23']
# ['DEU', 'ANDROID', 'FEMALE', '0', '18']
# ['BRA', 'ANDROID', 'FEMALE', '24', '30']
# ['USA', 'ANDROID', 'MALE', '24', '30']
# ['CAN', 'ANDROID', 'FEMALE', '0', '18']
# ['TUR', 'IOS', 'FEMALE', '31', '40']
# ['FRA', 'ANDROID', 'MALE', '19', '23']
# ['USA', 'ANDROID', 'MALE', '41', '66']
# ['FRA', 'IOS', 'FEMALE', '24', '30']
# ['BRA', 'ANDROID', 'FEMALE', '31', '40']
# ['TUR', 'ANDROID', 'FEMALE', '24', '30']
# ['USA', 'IOS', 'MALE', '31', '40']
# ['USA', 'IOS', 'MALE', '24', '30']
# ['BRA', 'ANDROID', 'FEMALE', '24', '30']
# ['TUR', 'IOS', 'MALE', '19', '23']
# ['USA', 'ANDROID', 'MALE', '24', '30']
# ['BRA', 'IOS', 'MALE', '31', '40']
# ['BRA', 'ANDROID', 'MALE', '19', '23']
# ['TUR', 'ANDROID', 'MALE', '19', '23']
# ['TUR', 'IOS', 'MALE', '41', '66']
# ['BRA', 'IOS', 'FEMALE', '31', '40']
# ['BRA', 'IOS', 'MALE', '41', '66']
# ['USA', 'IOS', 'FEMALE', '31', '40']
# ['USA', 'IOS', 'FEMALE', '24', '30']
# ['CAN', 'ANDROID', 'FEMALE', '24', '30']
# ['FRA', 'ANDROID', 'MALE', '0', '18']
# ['DEU', 'ANDROID', 'MALE', '24', '30']
#    customers_level_based      PRICE SEGMENT
# 63  FRA_IOS_FEMALE_31_40  32.818182       C
